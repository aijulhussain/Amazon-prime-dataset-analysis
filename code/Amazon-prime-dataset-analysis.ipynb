# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd
# Out:
# /home/aijul

# %%
df_credits = pd.read_csv("/home/aijul/Amazon Prime Dataset analysis/dataset/credits.csv")
df_title = pd.read_csv("/home/aijul/Amazon Prime Dataset analysis/dataset/titles.csv")

# %%
df_credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
df_title.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
df_credits.shape
# Out:
# (124235, 5)

# %%
df_title.shape
# Out:
# (9871, 15)

# %%
df_title = df_title.merge(df_credits,on='id')

# %%
df_title.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3               NaN       78
# 4               NaN       78
#
#                                               genres production_countries  \
# ...

# %%
df_title.shape
# Out:
# (124347, 19)

# %%
df_dataset= df_title

# %%
df_dataset.shape
# Out:
# (124347, 19)

# %%
#total element in the dataset
df_dataset.size
# Out:
# 2362593

# %%
df_dataset.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
df_dataset.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# person_id                 int64
# name                     object
# character                object
# role                     object
# dtype: object

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124347 non-null  object
#  1   title                 124347 non-null  object
#  2   type                  124347 non-null  object
#  3   description           124256 non-null  object
#  4   release_year          124347 non-null  int64
#  5   age_certification     56707 non-null   object
#  6   runtime               124347 non-null  int64
#  7   genres                124347 non-null  object
#  8   production_countries  124347 non-null  object
#  9   seasons               8153 non-null    float64
#  10  imdb_id               119044 non-null  object
#  11  imdb_score            118296 non-null  float64
#  12  imdb_votes            118272 non-null  float64
#  13  tmdb_popularity       124332 non-null  float64
# ...

# %% [markdown]
# # Remove duplicates

# %%
df_dataset[df_dataset.duplicated()]
# Out:
#              id                  title   type  \
# 9156    tm89134  The Gunman From Bodie  MOVIE
# 9157    tm89134  The Gunman From Bodie  MOVIE
# 9158    tm89134  The Gunman From Bodie  MOVIE
# 9159    tm89134  The Gunman From Bodie  MOVIE
# 9160    tm89134  The Gunman From Bodie  MOVIE
# ...         ...                    ...    ...
# 13125  tm137955          Broken Dreams  MOVIE
# 13126  tm137955          Broken Dreams  MOVIE
# 13127  tm137955          Broken Dreams  MOVIE
# 13128  tm137955          Broken Dreams  MOVIE
# 13129  tm137955          Broken Dreams  MOVIE
#
#                                              description  release_year  \
# 9156   The Rough Riders are after a gang of rustlers....          1941
# 9157   The Rough Riders are after a gang of rustlers....          1941
# 9158   The Rough Riders are after a gang of rustlers....          1941
# 9159   The Rough Riders are after a gang of rustlers....          1941
# ...

# %%
df_dataset.drop_duplicates(inplace= True)

# %%
df_dataset.shape
# Out:
# (124179, 19)

# %%
df_dataset.isnull()
# Out:
#            id  title   type  description  release_year  age_certification  \
# 0       False  False  False        False         False              False
# 1       False  False  False        False         False              False
# 2       False  False  False        False         False              False
# 3       False  False  False        False         False               True
# 4       False  False  False        False         False               True
# ...       ...    ...    ...          ...           ...                ...
# 124342  False  False  False        False         False               True
# 124343  False  False  False        False         False               True
# 124344  False  False  False        False         False               True
# 124345  False  False  False        False         False               True
# 124346  False  False  False        False         False               True
#
#         runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# ...

# %%
#Count of all null values in each column
df_dataset.isnull().sum()
# Out:
# id                           0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67472
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116026
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10169
# person_id                    0
# name                         0
# character                16277
# role                         0
# dtype: int64

# %% [markdown]
# ***Heat Map***

# %%
sns.heatmap(df_dataset.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***Geting the information about the particular element***

# %%
 df_dataset[df_dataset['title'].isin(["House of Cards"])]
# Out:
#             id           title  type  \
# 31585  ts24149  House of Cards  SHOW
# 31586  ts24149  House of Cards  SHOW
# 31587  ts24149  House of Cards  SHOW
# 31588  ts24149  House of Cards  SHOW
# 31589  ts24149  House of Cards  SHOW
# 31590  ts24149  House of Cards  SHOW
# 31591  ts24149  House of Cards  SHOW
# 31592  ts24149  House of Cards  SHOW
# 31593  ts24149  House of Cards  SHOW
# 31594  ts24149  House of Cards  SHOW
# 31595  ts24149  House of Cards  SHOW
#
#                                              description  release_year  \
# 31585  Frustrated at a new moderate Conservative gove...          1990
# 31586  Frustrated at a new moderate Conservative gove...          1990
# 31587  Frustrated at a new moderate Conservative gove...          1990
# 31588  Frustrated at a new moderate Conservative gove...          1990
# 31589  Frustrated at a new moderate Conservative gove...          1990
# 31590  Frustrated at a new moderate Conservative gove...          1990
# ...

# %% [markdown]
# # In which year highet no. of TY shows and  movies were released? Show with bar Graph.***

# %%
df_dataset.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# person_id                 int64
# name                     object
# character                object
# role                     object
# dtype: object

# %%
df_dataset['release_year'].value_counts()
# Out:
# 2019    8457
# 2021    7510
# 2020    6924
# 2018    6917
# 2017    6296
#         ...
# 1922      44
# 1914      33
# 1928      28
# 1912      11
# 1917       8
# Name: release_year, Length: 110, dtype: int64

# %% [markdown]
# # Bar Graph

# %%
df_dataset['release_year'].value_counts().plot(kind='bar', figsize=(25, 10), fontsize=14)
plt.xlabel("YEARS", fontsize= 20, fontweight ='bold')
plt.ylabel("No. of movies", fontsize= 20, fontweight ='bold')
plt.title("Highet no. of TY shows and movies were released", y=1.02, fontsize= 20, fontweight ='bold');

# %% [markdown]
# # How many movie and tv shows are in the  dataset?

# %%
df_dataset.groupby('type').type.count()
# Out:
# type
# MOVIE    116026
# SHOW       8153
# Name: type, dtype: int64

# %%
sns.countplot(df_dataset['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# # Show all the movies that were released in year 2010.

# %%
df_dataset[(df_dataset['type']== 'MOVIE') & (df_dataset['release_year']== 2010)]
# Out:
#              id            title   type  \
# 48288  tm104347  I Saw the Devil  MOVIE
# 48289  tm104347  I Saw the Devil  MOVIE
# 48290  tm104347  I Saw the Devil  MOVIE
# 48291  tm104347  I Saw the Devil  MOVIE
# 48292  tm104347  I Saw the Devil  MOVIE
# ...         ...              ...    ...
# 64864  tm457737        Body Blow  MOVIE
# 64865  tm457737        Body Blow  MOVIE
# 64866  tm457737        Body Blow  MOVIE
# 64867  tm457737        Body Blow  MOVIE
# 64868  tm457737        Body Blow  MOVIE
#
#                                              description  release_year  \
# 48288  Kyung-chul is a dangerous psychopath who kills...          2010
# 48289  Kyung-chul is a dangerous psychopath who kills...          2010
# 48290  Kyung-chul is a dangerous psychopath who kills...          2010
# 48291  Kyung-chul is a dangerous psychopath who kills...          2010
# 48292  Kyung-chul is a dangerous psychopath who kills...          2010
# ...

# %% [markdown]
# #  show only the titles of all TV Shows that were released in india only.

# %%
#df_dataset['production_countries'] = df_dataset['production_countries'].apply(lambda x: ' '.join(x))#list to string
df_dataset['production_countries'] = df_dataset['production_countries'].apply(lambda x: x[2:-2])

# %%
df_dataset.head(2)
# Out:
#         id              title  type  \
# 0  ts20945  The Three Stooges  SHOW
# 1  ts20945  The Three Stooges  SHOW
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
#
#                                               genres production_countries  \
# 0  ['comedy', 'family', 'animation', 'action', 'f...                   US
# 1  ['comedy', 'family', 'animation', 'action', 'f...                   US
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0     26.0  tt0850645         8.6      1092.0           15.424         7.6
# 1     26.0  tt0850645         8.6      1092.0           15.424         7.6
#
#    person_id        name character   role
# 0      59401  Joe Besser       Joe  ACTOR
# ...

# %%
df_dataset[(df_dataset['type']== 'SHOW') & (df_dataset['production_countries']== 'US')]
# Out:
#              id              title  type  \
# 0       ts20945  The Three Stooges  SHOW
# 1       ts20945  The Three Stooges  SHOW
# 2       ts20945  The Three Stooges  SHOW
# 2285    ts55748    What's My Line?  SHOW
# 16488   ts20005        I Love Lucy  SHOW
# ...         ...                ...   ...
# 123200  ts17643              Drift  SHOW
# 123201  ts17643              Drift  SHOW
# 123202  ts17643              Drift  SHOW
# 123203  ts17643              Drift  SHOW
# 123204  ts17643              Drift  SHOW
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 2285    Four panelists must determine guests' occupati...          1950
# 16488   Cuban Bandleader Ricky Ricardo would be happy ...          1951
# ...

# %%
df_dataset[(df_dataset['type']== 'SHOW') & (df_dataset['production_countries']== 'US')]['title']
# Out:
# 0         The Three Stooges
# 1         The Three Stooges
# 2         The Three Stooges
# 2285        What's My Line?
# 16488           I Love Lucy
#                 ...
# 123200                Drift
# 123201                Drift
# 123202                Drift
# 123203                Drift
# 123204                Drift
# Name: title, Length: 2218, dtype: object

# %% [markdown]
# # Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df_dataset.head(2)
# Out:
#         id              title  type  \
# 0  ts20945  The Three Stooges  SHOW
# 1  ts20945  The Three Stooges  SHOW
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
#
#                                               genres production_countries  \
# 0  ['comedy', 'family', 'animation', 'action', 'f...                   US
# 1  ['comedy', 'family', 'animation', 'action', 'f...                   US
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0     26.0  tt0850645         8.6      1092.0           15.424         7.6
# 1     26.0  tt0850645         8.6      1092.0           15.424         7.6
#
#    person_id        name character   role
# 0      59401  Joe Besser       Joe  ACTOR
# ...

# %%
df_dataset['genres'] = df_dataset['genres'].apply(lambda x: ', '.join(x))#list to string

# %%
df_dataset.head(2)
# Out:
#         id              title  type  \
# 0  ts20945  The Three Stooges  SHOW
# 1  ts20945  The Three Stooges  SHOW
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
#
#                                               genres production_countries  \
# 0  [, ', c, o, m, e, d, y, ', ,,  , ', f, a, m, i...                   US
# 1  [, ', c, o, m, e, d, y, ', ,,  , ', f, a, m, i...                   US
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0     26.0  tt0850645         8.6      1092.0           15.424         7.6
# 1     26.0  tt0850645         8.6      1092.0           15.424         7.6
#
#    person_id        name character   role
# 0      59401  Joe Besser       Joe  ACTOR
# ...

# %%
df_dataset[(df_dataset['type']== 'MOVIE') & (df_dataset['genres']== 'comedy') | (df_dataset['production_countries']== 'UK')]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %% [markdown]
# # In how many movies/shows, Tom Cruise was cast ?

# %%
df_dataset[df_dataset['name']== 'Tom Cruise']
# Out:
#                id                              title   type  \
# 30688    tm120192                 The Color of Money  MOVIE
# 31175    tm127028                               Taps  MOVIE
# 49602     tm46993                           Valkyrie  MOVIE
# 51585     tm82597                    Lions for Lambs  MOVIE
# 55571    tm860463  Valkyrie: The Plot to Kill Hitler  MOVIE
# 65036     tm53381                       Jack Reacher  MOVIE
# 116964  tm1069983                                Val  MOVIE
#
#                                               description  release_year  \
# 30688   Former pool hustler "Fast Eddie" Felson decide...          1986
# 31175   Military cadets take extreme measures to ensur...          1981
# 49602   Wounded in Africa during World War II, Nazi Co...          2008
# 51585   Three stories told simultaneously in ninety mi...          2007
# 55571   Recalling Operation Valkyrie, a failed plot de...          2008
# ...

# %% [markdown]
# # How many Movies got the more than 8 imdb rating, in India ?

# %%
df_dataset[(df_dataset['type']=='MOVIE') & (df_dataset['imdb_score']>8) & (df_dataset['production_countries']=='IN')].shape
# Out:
# (730, 19)

# %% [markdown]
# # How many Movies got the more than 8 imdb rating, in India after 2016 ?

# %%
df_dataset[(df_dataset['type']=='MOVIE') & (df_dataset['imdb_score']>8) & (df_dataset['production_countries']> 'IN') & (df_dataset['release_year']>2016)].shape
# Out:
# (267, 19)

# %% [markdown]
# # What is the maximum duration of a Movie/Show on Amazon Prime ?

# %%
df_dataset['runtime'].unique()
# Out:
# array([ 19,  78, 171,  92,  94,  96, 130,  66,  95,  57, 197, 101,  63,
#        104,  99,  70, 115, 106, 100, 128,  89, 112, 103, 149,  83,  88,
#        109,  90,  93,  76, 105, 102, 120, 122, 116,  67,  80, 123, 134,
#         69, 113,  86,  53, 110,  61,  77, 118, 119,  79,  75, 150,  58,
#        133,  45, 108,  38, 111, 258,  68,  30,  73,  98,  72,  32,  84,
#         64,  81,  87,  74, 145,  60, 132,  65, 140,  71,  59,  85,  91,
#        228,  42,  56,  52,  48,  47,  62, 117,  20,  55,  54,  82, 143,
#         41, 158, 138,  97, 121,  50,  22,  51, 153,  40, 170, 328,  36,
#        129, 125, 237,  29, 107, 163, 260, 124,  23,  24,  26,  25, 246,
#        157, 165, 139, 208,  13, 137, 127, 126, 189, 136, 114,  28, 147,
#        159,  46, 176, 181, 161, 177, 148, 152, 180, 160, 178, 141, 168,
#        151, 155, 175,  27, 131, 154, 146, 182, 173, 156,  21,  10,   9,
#         43, 251, 174,  15, 172, 179, 142, 162, 166, 135, 144, 194,  44,
# ...

# %% [markdown]
# # Which individual country has the Highest No. of TV Shows ?

# %%
df_dataset[df_dataset['type']=='SHOW'].production_countries.value_counts().head(1)
# Out:
# US    2218
# Name: production_countries, dtype: int64
